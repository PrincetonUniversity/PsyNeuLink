# %% [markdown]
# # Gating with User Defined Functions
#
# Here, we will create a simple gating mechanism that uses a wave function as the gating function.
#
# *Installation and Setup*

# %%
# %%capture
# %pip install psyneulink

# %%
import psyneulink as pnl
import numpy as np

# %% [markdown]
# First, we create a simple user-defined function (UDF) that will be used as the gating function. It expects an input with two elements: frequency and time. The output is a sinusoidal wave based on the frequency and time, with a phase and amplitude that can be controlled.

# %%
def my_sinusoidal_fct(input=[0, 0],
                     phase=0,
                     amplitude=1):
    frequency = input[0]
    t = input[1]
    return amplitude * np.sin(2 * np.pi * frequency * t + phase)

# %%
my_sinusoidal_udf = pnl.UserDefinedFunction(
    custom_function=my_sinusoidal_fct,
    phase=1,
    amplitude=1,
    params = {
        pnl.MULTIPLICATIVE_PARAM: 'phase',
        pnl.ADDITIVE_PARAM: 'amplitude'
    }
)
# TODO: finish this up after UDF is fixed
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 my_sinusoidal_udf = pnl.UserDefinedFunction(
#       2     custom_function=my_sinusoidal_fct,
#       3     phase=1,
#       4     amplitude=1,
#       5     params = {
#       6         pnl.MULTIPLICATIVE_PARAM: 'phase',
#       7         pnl.ADDITIVE_PARAM: 'amplitude'
#       8     }
#       9 )
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File <@beartype(psyneulink.core.components.functions.userdefinedfunction.UserDefinedFunction.__init__) at 0x2a97d7ec0>:66, in __init__(__beartype_object_6383641280, __beartype_object_6378930080, __beartype_object_6378973424, __beartype_object_6378973552, __beartype_object_6379044912, __beartype_object_6378973616, __beartype_object_6379044992, __beartype_get_violation, __beartype_conf, __beartype_args_name_keywordable, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/functions/userdefinedfunction.py:597, in UserDefinedFunction.__init__(self, custom_function, default_variable, params, owner, prefs, stateful_parameter, **kwargs)
#     588     cust_fct_name = repr(custom_function.__name__)
#     589     raise FunctionError("Value passed as \'default_variable\' for {} {} ({}) conflicts with specification of "
#     590                         "first argument in constructor for {} itself ({}). "
#     591                         "Try modifying specification of \'default_variable\' "
#    (...)    594                         format(self.__class__.__name__, cust_fct_name, default_variable,
#     595                                cust_fct_name, cust_fct_variable, cust_fct_name, owner_name, cust_fct_name))
# --> 597 super().__init__(
#     598     default_variable=default_variable,
#     599     custom_function=custom_function,
#     600     params=params,
#     601     owner=owner,
#     602     prefs=prefs,
#     603     **self.cust_fct_params
#     604 )
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/functions/function.py:690, in Function_Base.__init__(self, default_variable, params, owner, name, prefs, context, **kwargs)
#     683 register_category(entry=self,
#     684                   base_class=Function_Base,
#     685                   registry=FunctionRegistry,
#     686                   name=name,
#     687                   )
#     688 self.owner = owner
# --> 690 super().__init__(
#     691     default_variable=default_variable,
#     692     param_defaults=params,
#     693     name=name,
#     694     prefs=prefs,
#     695     **kwargs
#     696 )
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/component.py:1189, in Component.__init__(self, default_variable, param_defaults, input_shapes, function, name, reset_stateful_function_when, prefs, function_params, **kwargs)
#    1186 else:
#    1187     self.reset_stateful_function_when = Never()
# -> 1189 parameter_values, function_params = self._parse_arguments(
#    1190     default_variable, param_defaults, input_shapes, function, function_params, kwargs
#    1191 )
#    1193 self._initialize_parameters(
#    1194     context=context,
#    1195     **parameter_values
#    1196 )
#    1198 var = call_with_pruned_args(
#    1199     self._handle_default_variable,
#    1200     **parameter_values
#    1201 )
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/component.py:2294, in Component._parse_arguments(self, default_variable, param_defaults, input_shapes, function, function_params, kwargs)
#    2289     function_params = {
#    2290         **kwargs,
#    2291         **function_params
#    2292     }
#    2293 else:
# -> 2294     self._validate_arguments(parameter_values)
#    2296 # self.parameters here still references <class>.parameters, but
#    2297 # only unchanging attributes are needed here
#    2298 for p in self.parameters:
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/component.py:2203, in Component._validate_arguments(self, parameter_values)
#    2197     source_specified = (
#    2198         passed_name in self._user_specified_args
#    2199         and (s_val is not None or alias.source.specify_none)
#    2200     )
#    2201     return alias_specified and source_specified
# -> 2203 illegal_passed_args = self._get_illegal_arguments(**parameter_values)
#    2205 conflicting_aliases = []
#    2206 unused_constructor_args = {}
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/component.py:1869, in Component._get_illegal_arguments(self, **kwargs)
#    1867 def _get_illegal_arguments(self, **kwargs) -> set:
#    1868     allowed_kwargs = self._get_allowed_arguments()
# -> 1869     return {
#    1870         k for k in kwargs
#    1871         if k not in allowed_kwargs and k in self._user_specified_args
#    1872     }
#
# File /Applications/PyCharm.app/Contents/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch.py:92, in trace_dispatch(py_db, frame, event, arg)
#      90 if _trace_dispatch is None:
#      91     return None
# ---> 92 return _trace_dispatch(py_db, frame, event, arg)
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1337, in _pydevd_bundle.pydevd_cython_darwin_311_64.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1597, in _pydevd_bundle.pydevd_cython_darwin_311_64.ThreadTracer.__call__()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1103, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1065, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:585, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.do_wait_suspend()
#
# File /Applications/PyCharm.app/Contents/plugins/python-ce/helpers/pydev/pydevd.py:1220, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1217         from_this_thread.append(frame_id)
#    1219 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1220     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /Applications/PyCharm.app/Contents/plugins/python-ce/helpers/pydev/pydevd.py:1235, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1232             self._call_mpl_hook()
#    1234         self.process_internal_commands()
# -> 1235         time.sleep(0.01)
#    1237 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1239 # process any stepping instructions
#
# KeyboardInterrupt:

# %% [markdown]
# Now, let's create our composition. It will consist of an input layer, an output layer, and a gating mechanism:
#
# First the input layer:

# %%
input_layer = pnl.ProcessingMechanism(
    name='Input',
    input_shapes=2,
    function=pnl.Logistic
)

# %%
input_layer.execute([0.5, 0.5])  # Test the input layer with some input
# Out:
# array([[0.62245933, 0.62245933]])

# %% [markdown]
# For the output layer, we will specify an additional output port that uses the udf earlier

# %%
output_layer = pnl.ProcessingMechanism(
    name='Output',
    input_shapes=2,
    output_ports={
        pnl.NAME: 'Output with UDF',
        pnl.VARIABLE: [(pnl.OWNER_VALUE,0), pnl.EXECUTION_COUNT],  # Here, we use the current value of the mechanism and the execution count as input to the UDF (current value -> frequency, execution count -> time)
        pnl.FUNCTION: my_sinusoidal_fct
    }
)
# Out:
# ---------------------------------------------------------------------------
# ComponentError                            Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 output_layer = pnl.ProcessingMechanism(
#       2     name='Output',
#       3     input_shapes=2,
#       4     output_ports={
#       5         pnl.NAME: 'Output with UDF',
#       6         pnl.VARIABLE: [(pnl.OWNER_VALUE,0), pnl.EXECUTION_COUNT],  # Here, we use the current value of the mechanism and the execution count as input to the UDF (current value -> frequency, execution count -> time)
#       7         pnl.FUNCTION: my_sinusoidal_fct
#       8     }
#       9 )
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File <@beartype(psyneulink.core.components.mechanisms.processing.processingmechanism.ProcessingMechanism.__init__) at 0x2aa2396c0>:110, in __init__(__beartype_object_11442928624, __beartype_get_violation, __beartype_conf, __beartype_object_11444643840, __beartype_object_6383641280, __beartype_object_6378930080, __beartype_object_6378973424, __beartype_object_6378973552, __beartype_object_6379044912, __beartype_object_6378973616, __beartype_object_6379044992, __beartype_args_name_keywordable, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/mechanisms/processing/processingmechanism.py:390, in ProcessingMechanism.__init__(self, default_variable, input_shapes, input_ports, output_ports, function, params, name, prefs, **kwargs)
#     378 @check_user_specified
#     379 @beartype
#     380 def __init__(self,
#    (...)    388              prefs:   Optional[ValidPrefSet] = None,
#     389              **kwargs):
# --> 390     super(ProcessingMechanism, self).__init__(default_variable=default_variable,
#     391                                               input_shapes=input_shapes,
#     392                                               input_ports=input_ports,
#     393                                               function=function,
#     394                                               output_ports=output_ports,
#     395                                               params=params,
#     396                                               name=name,
#     397                                               prefs=prefs,
#     398                                               **kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/mechanisms/processing/processingmechanism.py:293, in ProcessingMechanism_Base.__init__(self, default_variable, input_shapes, input_ports, function, output_ports, params, name, prefs, context, **kwargs)
#     270 @check_user_specified
#     271 def __init__(self,
#     272              default_variable=None,
#    (...)    281              **kwargs
#     282              ):
#     283     """Abstract class for processing mechanisms
#     284
#     285     :param variable: (value)
#    (...)    290     :param context: (str)
#     291     """
# --> 293     super().__init__(default_variable=default_variable,
#     294                      input_shapes=input_shapes,
#     295                      input_ports=input_ports,
#     296                      function=function,
#     297                      output_ports=output_ports,
#     298                      params=params,
#     299                      name=name,
#     300                      prefs=prefs,
#     301                      context=context,
#     302                      **kwargs
#     303                      )
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/mechanisms/mechanism.py:1777, in Mechanism_Base.__init__(self, default_variable, input_shapes, input_ports, input_labels, function, output_ports, output_labels, params, name, prefs, context, **kwargs)
#    1771 from psyneulink.core.components.ports.outputport import OutputPort
#    1772 register_category(entry=OutputPort,
#    1773                   base_class=Port_Base,
#    1774                   registry=self._portRegistry,
#    1775                   )
# -> 1777 super(Mechanism_Base, self).__init__(
#    1778     default_variable=default_variable,
#    1779     input_shapes=input_shapes,
#    1780     function=function,
#    1781     param_defaults=params,
#    1782     prefs=prefs,
#    1783     name=name,
#    1784     input_ports=input_ports,
#    1785     output_ports=output_ports,
#    1786     input_labels_dict=input_labels,
#    1787     output_labels_dict=output_labels,
#    1788     **kwargs
#    1789 )
#    1791 # FIX: 10/3/17 - IS THIS CORRECT?  SHOULD IT BE INITIALIZED??
#    1792 self._status = INITIALIZING
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/shellclasses.py:82, in Mechanism.__init__(self, default_variable, input_shapes, function, param_defaults, name, prefs, **kwargs)
#      73 @check_user_specified
#      74 def __init__(self,
#      75              default_variable=None,
#    (...)     80              prefs=None,
#      81              **kwargs):
# ---> 82     super().__init__(default_variable=default_variable,
#      83                      input_shapes=input_shapes,
#      84                      function=function,
#      85                      param_defaults=param_defaults,
#      86                      name=name,
#      87                      prefs=prefs,
#      88                      **kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/component.py:1316, in Component.__init__(self, default_variable, param_defaults, input_shapes, function, name, reset_stateful_function_when, prefs, function_params, **kwargs)
#    1311 self._instantiate_value(context=context)
#    1313 # INSTANTIATE ATTRIBUTES AFTER FUNCTION
#    1314 # Stub for methods that need to be executed after instantiating function
#    1315 #    (e.g., instantiate_output_port in Mechanism)
# -> 1316 self._instantiate_attributes_after_function(context=context)
#    1318 self._validate(context=context)
#    1320 self.initialization_status = ContextFlags.INITIALIZED
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/mechanisms/mechanism.py:2221, in Mechanism_Base._instantiate_attributes_after_function(self, context)
#    2218 def _instantiate_attributes_after_function(self, context=None):
#    2219     from psyneulink.core.components.ports.parameterport import _instantiate_parameter_port
# -> 2221     self._instantiate_output_ports(context=context)
#    2222     # instantiate parameter ports from UDF custom parameters if necessary
#    2223     try:
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/mechanisms/processing/processingmechanism.py:457, in ProcessingMechanism._instantiate_output_ports(self, context)
#     453         return _instantiate_output_ports(owner=self, output_ports=output_ports, context=context)
#     455 # Multiple but unequal numbers of InputPorts and OutputPorts, so follow default protocol
#     456 #   (i.e., assign value of all OutputPorts to the first item of Mechanism's value unless otherwise specified)
# --> 457 return super()._instantiate_output_ports(context=context)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/mechanisms/mechanism.py:2270, in Mechanism_Base._instantiate_output_ports(self, context)
#    2264 """Call Port._instantiate_output_ports to instantiate orderedDict of OutputPort(s)
#    2265
#    2266 This is a stub, implemented to allow Mechanism subclasses to override _instantiate_output_ports
#    2267     or process InputPorts before and/or after call to _instantiate_output_ports
#    2268 """
#    2269 from psyneulink.core.components.ports.outputport import _instantiate_output_ports
# -> 2270 _instantiate_output_ports(owner=self, output_ports=self.output_ports, context=context)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/ports/outputport.py:1469, in _instantiate_output_ports(owner, output_ports, context)
#    1466     port_types = OutputPort
#    1468 context.string = context.string or '_instantiate_output_ports'
# -> 1469 port_list = _instantiate_port_list(owner=owner,
#    1470                                      port_list=output_ports,
#    1471                                      port_types=port_types,
#    1472                                      port_Param_identifier=OUTPUT_PORT,
#    1473                                      reference_value=reference_value,
#    1474                                      reference_value_name="output",
#    1475                                      context=context)
#    1477 # Call from Mechanism.add_ports, so add to rather than assign output_ports (i.e., don't replace)
#    1478 if context.source & (ContextFlags.COMMAND_LINE | ContextFlags.METHOD):
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/ports/port.py:2553, in _instantiate_port_list(owner, port_list, port_types, port_Param_identifier, reference_value, reference_value_name, context)
#    2547 # for index, port_spec, port_type in enumerate(zip(port_list, port_types)):
#    2548 for index, port_spec, port_type in zip(list(range(len(port_list))), port_list, port_types):
#    2549     # # Get name of port, and use as index to assign to ports ContentAddressableList
#    2550     # default_name = port_type._assign_default_port_Name(port_type)
#    2551     # name = default_name or None
# -> 2553     port = _instantiate_port(port_type=port_type,
#    2554                                owner=owner,
#    2555                                reference_value=reference_value[index],
#    2556                                reference_value_name=reference_value_name,
#    2557                                port_spec=port_spec,
#    2558                                # name=name,
#    2559                                context=context)
#    2560     # automatically generate any Projections to InputPort or ParameterPort
#    2561     # (e.g. if InputPort was specified using the OutputPort of another Mechanism,
#    2562     #       or a ParameterPort was specified using the ControlSignal of a ControlMechanism)
#    2563     try:
#
# File <@beartype(psyneulink.core.components.ports.port._instantiate_port) at 0x2aa06d300>:82, in _instantiate_port(__beartype_object_4433920224, __beartype_get_violation, __beartype_conf, __beartype_object_11433607296, __beartype_object_4473850368, __beartype_args_name_keywordable, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/ports/port.py:2736, in _instantiate_port(port_type, owner, reference_value, name, variable, params, prefs, context, **port_spec)
#    2733         del port_spec_dict[PARAMS][REFERENCE_VALUE_NAME]
#    2735     # Implement default Port
# -> 2736     port = port_type(**port_spec_dict, context=context)
#    2738 # FIX LOG: ADD NAME TO LIST OF MECHANISM'S VALUE ATTRIBUTES FOR USE BY LOGGING ENTRIES
#    2739     # This is done here to register name with Mechanism's portValues[] list
#    2740     # It must be consistent with value setter method in Port
#    (...)   2744 #                NOT SURE WHAT THE PURPOSE IS
#    2745 #     setattr(owner, port.name+'.value', port.value)
#    2747     port._validate_against_reference_value(reference_value)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/context.py:745, in handle_external_context.<locals>.decorator.<locals>.wrapper(context, *args, **kwargs)
#     742             pass
#     744 try:
# --> 745     return func(*args, context=context, **kwargs)
#     746 except TypeError as e:
#     747     # context parameter may be passed as a positional arg
#     748     if (
#     749         f"{func.__name__}() got multiple values for argument"
#     750         not in str(e)
#     751     ):
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/ports/outputport.py:971, in OutputPort.__init__(self, owner, reference_value, variable, input_shapes, function, projections, params, name, prefs, index, assign, **kwargs)
#     963     self._variable = variable
#     965 # FIX: 5/26/16
#     966 # IMPLEMENTATION NOTE:
#     967 # Consider adding self to owner.output_ports here (and removing from ControlProjection._instantiate_sender)
#     968 #  (test for it, and create if necessary, as per OutputPorts in ControlProjection._instantiate_sender),
#     969
#     970 # Validate sender (as variable) and params
# --> 971 super().__init__(
#     972     owner,
#     973     variable=variable,
#     974     input_shapes=input_shapes,
#     975     projections=projections,
#     976     params=params,
#     977     name=name,
#     978     prefs=prefs,
#     979     context=context,
#     980     function=function,
#     981     index=index,
#     982     assign=assign,
#     983     **kwargs
#     984 )
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File <@beartype(psyneulink.core.components.ports.port.Port_Base.__init__) at 0x2a97fb100>:36, in __init__(__beartype_object_11433607296, __beartype_get_violation, __beartype_conf, __beartype_args_name_keywordable, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/ports/port.py:1101, in Port_Base.__init__(self, owner, variable, input_shapes, projections, function, params, name, prefs, context, **kwargs)
#    1093 register_category(entry=self,
#    1094                   base_class=Port_Base,
#    1095                   name=name,
#    1096                   registry=owner._portRegistry,
#    1097                   # sub_group_attr='owner',
#    1098                   )
#    1100 # VALIDATE VARIABLE, PARAM_SPECS, AND INSTANTIATE self.function
# -> 1101 super(Port_Base, self).__init__(
#    1102     default_variable=variable,
#    1103     input_shapes=input_shapes,
#    1104     function=function,
#    1105     projections=projections,
#    1106     param_defaults=params,
#    1107     name=name,
#    1108     prefs=prefs,
#    1109     **kwargs
#    1110 )
#    1112 # IMPLEMENTATION NOTE:  MOVE TO COMPOSITION ONCE THAT IS IMPLEMENTED
#    1113 # INSTANTIATE PROJECTIONS SPECIFIED IN projections ARG OR params[PROJECTIONS:<>]
#    1114 if self.projections is not None:
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/component.py:1309, in Component.__init__(self, default_variable, param_defaults, input_shapes, function, name, reset_stateful_function_when, prefs, function_params, **kwargs)
#    1304 function = self._instantiate_attributes_before_function(function=function, context=context) or function
#    1306 # INSTANTIATE FUNCTION
#    1307 #    - assign initial function parameter values from ParameterPorts,
#    1308 #    - assign function's output to self.defaults.value (based on call of self.execute)
# -> 1309 self._instantiate_function(function=function, function_params=function_params, context=context)
#    1311 self._instantiate_value(context=context)
#    1313 # INSTANTIATE ATTRIBUTES AFTER FUNCTION
#    1314 # Stub for methods that need to be executed after instantiating function
#    1315 #    (e.g., instantiate_output_port in Mechanism)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/ports/port.py:1214, in Port_Base._instantiate_function(self, function, function_params, context)
#    1211     self.defaults.variable = [self.defaults.variable]
#    1212     var_is_matrix = True
# -> 1214 super()._instantiate_function(function=function, function_params=function_params, context=context)
#    1216 # If it is a matrix, remove from list in which it was embedded after instantiating and evaluating function
#    1217 if var_is_matrix:
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/component.py:3208, in Component._instantiate_function(self, function, function_params, context)
#    3205 # Specification is a standard python function, so wrap as a UserDefnedFunction
#    3206 # Note:  parameter_ports for function's parameters will be created in_instantiate_attributes_after_function
#    3207 if isinstance(function, (types.FunctionType, str)):
# -> 3208     function = UserDefinedFunction(
#    3209         default_variable=function_variable,
#    3210         custom_function=function,
#    3211         owner=self,
#    3212         context=context,
#    3213         **function_params,
#    3214     )
#    3216 # Specification is an already implemented Function
#    3217 elif isinstance(function, Function):
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File <@beartype(psyneulink.core.components.functions.userdefinedfunction.UserDefinedFunction.__init__) at 0x2a97d7ec0>:66, in __init__(__beartype_object_6383641280, __beartype_object_6378930080, __beartype_object_6378973424, __beartype_object_6378973552, __beartype_object_6379044912, __beartype_object_6378973616, __beartype_object_6379044992, __beartype_get_violation, __beartype_conf, __beartype_args_name_keywordable, __beartype_check_meta, __beartype_func, *args, **kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/functions/userdefinedfunction.py:597, in UserDefinedFunction.__init__(self, custom_function, default_variable, params, owner, prefs, stateful_parameter, **kwargs)
#     588     cust_fct_name = repr(custom_function.__name__)
#     589     raise FunctionError("Value passed as \'default_variable\' for {} {} ({}) conflicts with specification of "
#     590                         "first argument in constructor for {} itself ({}). "
#     591                         "Try modifying specification of \'default_variable\' "
#    (...)    594                         format(self.__class__.__name__, cust_fct_name, default_variable,
#     595                                cust_fct_name, cust_fct_variable, cust_fct_name, owner_name, cust_fct_name))
# --> 597 super().__init__(
#     598     default_variable=default_variable,
#     599     custom_function=custom_function,
#     600     params=params,
#     601     owner=owner,
#     602     prefs=prefs,
#     603     **self.cust_fct_params
#     604 )
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/functions/function.py:690, in Function_Base.__init__(self, default_variable, params, owner, name, prefs, context, **kwargs)
#     683 register_category(entry=self,
#     684                   base_class=Function_Base,
#     685                   registry=FunctionRegistry,
#     686                   name=name,
#     687                   )
#     688 self.owner = owner
# --> 690 super().__init__(
#     691     default_variable=default_variable,
#     692     param_defaults=params,
#     693     name=name,
#     694     prefs=prefs,
#     695     **kwargs
#     696 )
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/globals/parameters.py:575, in check_user_specified.<locals>.check_user_specified_wrapper(self, *args, **kwargs)
#     572     self._prev_constructor = constructor
#     574 self._prev_kwargs = kwargs
# --> 575 return func(self, *args, **orig_kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/component.py:1189, in Component.__init__(self, default_variable, param_defaults, input_shapes, function, name, reset_stateful_function_when, prefs, function_params, **kwargs)
#    1186 else:
#    1187     self.reset_stateful_function_when = Never()
# -> 1189 parameter_values, function_params = self._parse_arguments(
#    1190     default_variable, param_defaults, input_shapes, function, function_params, kwargs
#    1191 )
#    1193 self._initialize_parameters(
#    1194     context=context,
#    1195     **parameter_values
#    1196 )
#    1198 var = call_with_pruned_args(
#    1199     self._handle_default_variable,
#    1200     **parameter_values
#    1201 )
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/component.py:2294, in Component._parse_arguments(self, default_variable, param_defaults, input_shapes, function, function_params, kwargs)
#    2289     function_params = {
#    2290         **kwargs,
#    2291         **function_params
#    2292     }
#    2293 else:
# -> 2294     self._validate_arguments(parameter_values)
#    2296 # self.parameters here still references <class>.parameters, but
#    2297 # only unchanging attributes are needed here
#    2298 for p in self.parameters:
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/psyneulink/core/components/component.py:2247, in Component._validate_arguments(self, parameter_values)
#    2245 unknown_args = illegal_passed_args.difference(unused_constructor_args)
#    2246 if len(unknown_args) > 0:
# -> 2247     raise create_illegal_argument_error([f"'{a}'" for a in unknown_args])
#    2249 # raise alias conflict error
#    2250 # can standardize these with above error, but leaving for now for consistency
#    2251 if len(conflicting_aliases) > 0:
#
# ComponentError: USER DEFINED FUNCTION-9 (owned by Output with UDF): Illegal arguments in constructor (type: UserDefinedFunction):
# 	'multiplicative_param'
# 	'additive_param'

# %% [markdown]
# Attention, here we use a function for the output port so the `value` of the mechanism and the content of the output port are not the same:

# %%
output_layer.execute([0.5, 0.5, 0.5])
# Out:
# array([[0.5, 0.5, 0.5]])

# %%
output_layer.output_port.value # <- since we only have one output port, we can access it directly
# Out:
# array([array([0.5, 0.5, 0.5]), array(1)], dtype=object)

# %% [markdown]
# Now, let's create a gating mechanism

# %%
gating = pnl.GatingMechanism(
   input_shapes=1,
    gating_signals=[
        output_layer.output_port,
    ]
)

# %% [markdown]
# Now, we can create the composition:

# %%
comp = pnl.Composition(
    pathways=[[input_layer, output_layer], [gating]],
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[150], line 2
#       1 comp = pnl.Composition(
# ----> 2     pathways=[[input_layer, output_layer], [gating]],
#       3 )
#
# NameError: name 'gating' is not defined
