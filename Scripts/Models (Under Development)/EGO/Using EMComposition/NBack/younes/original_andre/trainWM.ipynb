# %%
import os
import torch as tr
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from utilsWM import *
# %load_ext autoreload
# %autoreload 2

# %%
from utilsWM import run_model_for_epochs, plot_train_accuracy, eval_by_ttype, plot_accuracy_by_trial_type 

# main wrapper 
def train_net_and_plot_accuracy(neps, seed, model_path, figure_path):
    """ 
    main wrapper for running experiment and plotting
    """
    
    np.random.seed(seed)
    tr.random.manual_seed(seed)
    
    ## setup task
    ssizeL = [2, 3] 
    sample_fn = lambda match,slure,clure: lambda S,C,N: single_nback_comparison(S,C,N,
              pr_match=match,pr_stim_lure=slure,pr_context_lure=clure
              )

    taskintL = [0,1]
    taskL_tr = [
         [taskintL[0],sample_fn(PMATCH,PSLURE,PCLURE),ssizeL[0]],
         [taskintL[1],sample_fn(PMATCH,PSLURE,PCLURE),ssizeL[1]],
        ]

    # init net
    indim = 2 * (CDIM + SDIM)
    hiddim = SDIM * 4
    net = FFWM(indim,hiddim)

    # train net
    score_tr, ttype = run_model_for_epochs(net,taskL_tr,
    training=True,neps_per_task=neps,
    )
    
    # save trained model
    np.save(model_path + "/train-score", score_tr)
    tr.save(net.state_dict(), model_path + "/trained-net.pt")

    # generates evaluation plots
    plot_train_accuracy(score_tr, ttype, ssizeL, figure_path)
    scores_by_ttype = eval_by_ttype(net, sample_fn, taskintL, ssizeL, neps=1000)
    plot_accuracy_by_trial_type(scores_by_ttype, taskintL, ssizeL, figure_path)

    return net

# %%
# run 
n_training_eps = 1000 ## 1000000
seed = 0 ## 0

figure_path = "OUTPUT_PATH"
model_path = "models"

ffwm = train_net_and_plot_accuracy(neps=n_training_eps, seed=seed,
            model_path=model_path, figure_path=figure_path)
# Out:
# Training WM...
# 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       5 figure_path = "OUTPUT_PATH"
#       6 model_path = "models"
# ----> 8 ffwm = train_net_and_plot_accuracy(neps=n_training_eps, seed=seed,
#       9             model_path=model_path, figure_path=figure_path)
#
# Cell In[2], line 30, in train_net_and_plot_accuracy(neps, seed, model_path, figure_path)
#      27 net = FFWM(indim,hiddim)
#      29 # train net
# ---> 30 score_tr, ttype = run_model_for_epochs(net,taskL_tr,
#      31 training=True,neps_per_task=neps,
#      32 )
#      34 # save trained model
#      35 np.save(model_path + "/train-score", score_tr)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/Scripts/Models (Under Development)/nback/younes/original_andre/utilsWM.py:64, in run_model_for_epochs(net, taskL, training, neps_per_task, verb)
#      62 # forward prop
#      63 inputL = [stim_t, stim_m, context_t, context_m]
# ---> 64 yhat = net(inputL, control_bias_int=control_int)
#      65 # eval
#      66 score[task_idx, ep] = maxsoftmax(yhat) == ytarget
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/Scripts/Models (Under Development)/nback/younes/original_andre/utilsWM.py:25, in FFWM.forward(self, inputL, control_bias_int)
#      23 """inputL is list of tensors"""
#      24 hid1_in = tr.cat(inputL, -1)
# ---> 25 hid1_act = self.hid1_layer(hid1_in).relu()
#      26 control_bias = self.embed_bias(tr.tensor(control_bias_int))
#      27 hid2_in = hid1_act + control_bias
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/GitHub/Princeton/PsyNeuLink/.venv/lib/python3.11/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
