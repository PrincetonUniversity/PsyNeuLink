# %%
# %load_ext autoreload
# %autoreload 2

from ego_revaluation import run_original_probabilistic
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
run_original_probabilistic.run()
# Out:
# Baseline (np.float64(0.9998663000676353), np.float64(0.536746059634835))
# Common reward (np.float64(1.0000010656710863), np.float64(0.5429540914471094))
